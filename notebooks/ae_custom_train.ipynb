# %%
import ae
import tensorflow as tf
from tensorflow.keras.losses import MeanSquaredError
from time import sleep
# Out:
# 2022-10-26 01:02:47.506006: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-26 01:02:47.641311: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-26 01:02:48.286304: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:/home/can/thesis_ws/devel/lib:/home/can/bfmc_ws/devel/lib:/opt/ros/noetic/lib
# ...

# %%
ds_dir = "../gtsrb/custom_cropped_train/12_14/"
IMG_HEIGHT = 48
IMG_WIDTH = 48
IMG_CHANNEL = 3
VAL_SIZE = 0.2

lr = 0.0005
batchSize = 64
epochs = 100
lossFunc = MeanSquaredError()

weight_dir = "../ae_weights/"
ds_name = "12_14"
model_name = "model1"
loss_type = "mse"
ds_type = "full"

autoencoder = ae.autoEncoder()
autoencoder.dataset(ds_dir, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL, VAL_SIZE)
ae_model = autoencoder.model1()
autoencoder.train(ae_model, lr, lossFunc, batchSize, epochs)
autoencoder.saveModel(weight_dir, ds_name, model_name, loss_type, ds_type)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [3], line 19
#      16 ds_type = "full"
#      18 autoencoder = ae.autoEncoder()
# ---> 19 autoencoder.dataset(ds_dir, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL, VAL_SIZE)
#      20 ae_model = autoencoder.model1()
#      21 autoencoder.train(ae_model, lr, lossFunc, batchSize, epochs)
#
# File ~/thesis_ws/src/notebooks/ae.py:22, in autoEncoder.dataset(self, dsPath, imgHeight, imgWidth, imgChannel, valSize)
#      20 self.img_shape = (imgHeight, imgWidth, imgChannel)
#      21 ts_db = os.path.join(dsPath)
# ---> 22 for img in os.listdir(ts_db):
#      23     image = Image.open(os.path.join(ts_db, img))
#      24     image = image.resize((imgHeight,imgWidth))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../gtsrb/custom_cropped_train/12_14/'

# %%
ds_dir = "../gtsrb/custom_cropped_train/12_17/"
IMG_HEIGHT = 48
IMG_WIDTH = 48
IMG_CHANNEL = 3
VAL_SIZE = 0.2

lr = 0.0005
batchSize = 64
epochs = 100
lossFunc = MeanSquaredError()

weight_dir = "../ae_weights/"
ds_name = "12_17"
model_name = "model1"
loss_type = "mse"
ds_type = "full"

autoencoder = ae.autoEncoder()
autoencoder.dataset(ds_dir, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL, VAL_SIZE)
ae_model = autoencoder.model1()
autoencoder.train(ae_model, lr, lossFunc, batchSize, epochs)
autoencoder.saveModel(weight_dir, ds_name, model_name, loss_type, ds_type)
# Out:
# Destructor called, Employee deleted.
# #All images:  3210
# Train image set shape:  (2568, 48, 48, 3) Validation image set shape:  (642, 48, 48, 3)
# Epoch 1/100
# 41/41 [==============================] - 2s 30ms/step - loss: 0.0828 - accuracy: 0.4556 - val_loss: 0.0524 - val_accuracy: 0.4904
# Epoch 2/100
# 41/41 [==============================] - 1s 18ms/step - loss: 0.0433 - accuracy: 0.5446 - val_loss: 0.0350 - val_accuracy: 0.5357
# Epoch 3/100
# 41/41 [==============================] - 1s 18ms/step - loss: 0.0288 - accuracy: 0.5481 - val_loss: 0.0254 - val_accuracy: 0.5565
# Epoch 4/100
# 41/41 [==============================] - 1s 18ms/step - loss: 0.0223 - accuracy: 0.5707 - val_loss: 0.0211 - val_accuracy: 0.5685
# Epoch 5/100
# 41/41 [==============================] - 1s 18ms/step - loss: 0.0181 - accuracy: 0.5906 - val_loss: 0.0169 - val_accuracy: 0.5910
# Epoch 6/100
# ...

# %%
ds_dir = "../gtsrb/custom_cropped_train/12_17_39/"
IMG_HEIGHT = 48
IMG_WIDTH = 48
IMG_CHANNEL = 3
VAL_SIZE = 0.2

lr = 0.0005
batchSize = 64
epochs = 100
lossFunc = MeanSquaredError()

weight_dir = "../ae_weights/"
ds_name = "12_17_39"
model_name = "model1"
loss_type = "mse"
ds_type = "full"

autoencoder = ae.autoEncoder()
autoencoder.dataset(ds_dir, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL, VAL_SIZE)
ae_model = autoencoder.model1()
autoencoder.train(ae_model, lr, lossFunc, batchSize, epochs)
autoencoder.saveModel(weight_dir, ds_name, model_name, loss_type, ds_type)
# Out:
# Destructor called, Employee deleted.
# #All images:  3510
# Train image set shape:  (2808, 48, 48, 3) Validation image set shape:  (702, 48, 48, 3)
# Epoch 1/100
# 44/44 [==============================] - 2s 30ms/step - loss: 0.0822 - accuracy: 0.4709 - val_loss: 0.0478 - val_accuracy: 0.5130
# Epoch 2/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0413 - accuracy: 0.5012 - val_loss: 0.0310 - val_accuracy: 0.5058
# Epoch 3/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0267 - accuracy: 0.5293 - val_loss: 0.0222 - val_accuracy: 0.5784
# Epoch 4/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0201 - accuracy: 0.6257 - val_loss: 0.0181 - val_accuracy: 0.6615
# Epoch 5/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0161 - accuracy: 0.6632 - val_loss: 0.0147 - val_accuracy: 0.6745
# Epoch 6/100
# ...

# %%
ds_dir = "../gtsrb/custom_cropped_train/14_39/"
IMG_HEIGHT = 48
IMG_WIDTH = 48
IMG_CHANNEL = 3
VAL_SIZE = 0.2

lr = 0.0005
batchSize = 64
epochs = 100
lossFunc = MeanSquaredError()

weight_dir = "../ae_weights/"
ds_name = "14_39"
model_name = "model1"
loss_type = "mse"
ds_type = "full"

autoencoder = ae.autoEncoder()
autoencoder.dataset(ds_dir, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL, VAL_SIZE)
ae_model = autoencoder.model1()
autoencoder.train(ae_model, lr, lossFunc, batchSize, epochs)
autoencoder.saveModel(weight_dir, ds_name, model_name, loss_type, ds_type)
# Out:
# Destructor called, Employee deleted.
# #All images:  1080
# Train image set shape:  (864, 48, 48, 3) Validation image set shape:  (216, 48, 48, 3)
# Epoch 1/100
# 14/14 [==============================] - 2s 53ms/step - loss: 0.1114 - accuracy: 0.5341 - val_loss: 0.0790 - val_accuracy: 0.4933
# Epoch 2/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0639 - accuracy: 0.5560 - val_loss: 0.0632 - val_accuracy: 0.5507
# Epoch 3/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0531 - accuracy: 0.5644 - val_loss: 0.0523 - val_accuracy: 0.5613
# Epoch 4/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0440 - accuracy: 0.5778 - val_loss: 0.0431 - val_accuracy: 0.6084
# Epoch 5/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0362 - accuracy: 0.6295 - val_loss: 0.0346 - val_accuracy: 0.6806
# Epoch 6/100
# ...

# %%
ds_dir = "../gtsrb/custom_cropped_train/17_39/"
IMG_HEIGHT = 48
IMG_WIDTH = 48
IMG_CHANNEL = 3
VAL_SIZE = 0.2

lr = 0.0005
batchSize = 64
epochs = 100
lossFunc = MeanSquaredError()

weight_dir = "../ae_weights/"
ds_name = "17_39"
model_name = "model1"
loss_type = "mse"
ds_type = "full"

autoencoder = ae.autoEncoder()
autoencoder.dataset(ds_dir, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL, VAL_SIZE)
ae_model = autoencoder.model1()
autoencoder.train(ae_model, lr, lossFunc, batchSize, epochs)
autoencoder.saveModel(weight_dir, ds_name, model_name, loss_type, ds_type)
# Out:
# Destructor called, Employee deleted.
# #All images:  1410
# Train image set shape:  (1128, 48, 48, 3) Validation image set shape:  (282, 48, 48, 3)
# Epoch 1/100
# 18/18 [==============================] - 2s 57ms/step - loss: 0.1124 - accuracy: 0.4831 - val_loss: 0.0883 - val_accuracy: 0.6012
# Epoch 2/100
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0805 - accuracy: 0.6191 - val_loss: 0.0779 - val_accuracy: 0.6011
# Epoch 3/100
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0532 - accuracy: 0.5180 - val_loss: 0.0452 - val_accuracy: 0.5706
# Epoch 4/100
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0397 - accuracy: 0.5495 - val_loss: 0.0392 - val_accuracy: 0.5489
# Epoch 5/100
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0360 - accuracy: 0.5788 - val_loss: 0.0357 - val_accuracy: 0.5604
# Epoch 6/100
# ...

# %%
ds_dir = "/home/can/thesis/gtsrb/custom_cropped_train/0_1_2_3_4_5/"
IMG_HEIGHT = 48
IMG_WIDTH = 48
IMG_CHANNEL = 3
VAL_SIZE = 0.2

lr = 0.0005
batchSize = 64
epochs = 100
lossFunc = MeanSquaredError()

weight_dir = "../ae_weights/"
ds_name = "0_1_2_3_4_5"
model_name = "model1"
loss_type = "mse"
ds_type = "full"

autoencoder = ae.autoEncoder()
autoencoder.dataset(ds_dir, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL, VAL_SIZE)
ae_model = autoencoder.model1()
autoencoder.train(ae_model, lr, lossFunc, batchSize, epochs)
autoencoder.saveModel(weight_dir, ds_name, model_name, loss_type, ds_type)
# Out:
# #All images:  9930
# Train image set shape:  (7944, 48, 48, 3) Validation image set shape:  (1986, 48, 48, 3)
# 2022-10-24 00:45:04.027925: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 00:45:04.051458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 00:45:04.051701: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
weight_file12_14 = "../ae_weights/12_14fullmodel1mse.h5"
ae12_14 = ae.autoEncoder()
model12_14 = ae12_14.loadModel(weight_file12_14)
test_path12 = "../gtsrb/damaged_signs/12/"
ae12_14.showResults(5, test_path12, model12_14, "ALL")
# Out:
# 22/22 [==============================] - 0s 6ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file12_14 = "../ae_weights/12_14fullmodel1mse.h5"
ae12_14 = ae.autoEncoder()
model12_14 = ae12_14.loadModel(weight_file12_14)
test_path14 = "../gtsrb/damaged_signs/14/dmg/"
ae12_14.showResults(5, test_path14, model12_14, "ALL")
# Out:
# 1/1 [==============================] - 0s 214ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file12_17 = "../ae_weights/12_17fullmodel1mse.h5"
ae12_17 = ae.autoEncoder()
model12_17 = ae12_17.loadModel(weight_file12_17)
test_path12 = "../gtsrb/damaged_signs/12/"
ae12_17.showResults(5, test_path12, model12_17, "ALL")
# Out:
# 22/22 [==============================] - 0s 3ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file12_17 = "../ae_weights/12_17fullmodel1mse.h5"
ae12_17 = ae.autoEncoder()
model12_17 = ae12_17.loadModel(weight_file12_17)
test_path17 = "../gtsrb/damaged_signs/17/dmg/"
ae12_17.showResults(5, test_path17, model12_17, "ALL")
# Out:
# Destructor called, Employee deleted.
# 1/1 [==============================] - 0s 417ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file12_17_39 = "../ae_weights/12_17_39fullmodel1mse.h5"
ae12_17_39 = ae.autoEncoder()
model12_17_39 = ae12_17_39.loadModel(weight_file12_17_39)
test_path12 = "../gtsrb/damaged_signs/12/"
ae12_17_39.showResults(5, test_path12, model12_17_39, "ALL")
# Out:
# 22/22 [==============================] - 0s 3ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file12_17_39 = "../ae_weights/12_17_39fullmodel1mse.h5"
ae12_17_39 = ae.autoEncoder()
model12_17_39 = ae12_17_39.loadModel(weight_file12_17_39)
# test_path12 = "../gtsrb/damaged_signs/17/"
ae12_17_39.showResults(5, test_path17, model12_17_39, "ALL")
# Out:
# Destructor called, Employee deleted.
# 1/1 [==============================] - 0s 161ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file12_17_39 = "../ae_weights/12_17_39fullmodel1mse.h5"
ae12_17_39 = ae.autoEncoder()
model12_17_39 = ae12_17_39.loadModel(weight_file12_17_39)
test_path39 = "../gtsrb/damaged_signs/39/dmg/"
ae12_17_39.showResults(4, test_path39, model12_17_39, "ALL")
# Out:
# Destructor called, Employee deleted.
# Destructor called, Employee deleted.
# 1/1 [==============================] - 0s 163ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file14_39 = "../ae_weights/14_39fullmodel1mse.h5"
ae14_39 = ae.autoEncoder()
model14_39 = ae14_39.loadModel(weight_file14_39)
#test_path12 = "../gtsrb/damaged_signs/14/"
ae14_39.showResults(5, test_path14, model14_39, "ALL")
# Out:
# WARNING:tensorflow:5 out of the last 26 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0ccf9e3e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 161ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
weight_file14_39 = "../ae_weights/14_39fullmodel1mse.h5"
ae14_39 = ae.autoEncoder()
model14_39 = ae14_39.loadModel(weight_file14_39)
#test_path12 = "../gtsrb/damaged_signs/14/"
ae14_39.showResults(4, test_path39, model14_39, "ALL")
# Out:
# Destructor called, Employee deleted.
# WARNING:tensorflow:6 out of the last 27 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0cd13684c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 164ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
weight_file17_39 = "../ae_weights/17_39fullmodel1mse.h5"
ae17_39 = ae.autoEncoder()
model17_39 = ae17_39.loadModel(weight_file17_39)
#test_path12 = "../gtsrb/damaged_signs/14/"
ae17_39.showResults(5, test_path17, model17_39, "ALL")
# Out:
# 1/1 [==============================] - 0s 163ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file17_39 = "../ae_weights/17_39fullmodel1mse.h5"
ae17_39 = ae.autoEncoder()
model17_39 = ae17_39.loadModel(weight_file17_39)
#test_path12 = "../gtsrb/damaged_signs/14/"
ae17_39.showResults(4, test_path39, model17_39, "ALL")
# Out:
# Destructor called, Employee deleted.
# 1/1 [==============================] - 0s 422ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import ae
import tensorflow as tf
from tensorflow.keras.losses import MeanSquaredError
from time import sleep
# Out:
# 2022-10-24 01:01:01.546156: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-24 01:01:01.716829: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-24 01:01:02.531045: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:/home/can/thesis_ws/devel/lib:/home/can/bfmc_ws/devel/lib:/opt/ros/noetic/lib
# ...

# %%
ds_dir = "/home/can/thesis/gtsrb/cropped_train/"
IMG_HEIGHT = 48
IMG_WIDTH = 48
IMG_CHANNEL = 3
VAL_SIZE = 0.2

lr = 0.0005
batchSize = 32
epochs = 100
lossFunc = MeanSquaredError()

weight_dir = "/home/can/thesis/ae_weights/"
ds_name = "cropped_all"
model_name = "model1"
loss_type = "mse"
ds_type = "full"

autoencoder = ae.autoEncoder()
autoencoder.dataset_all(ds_dir, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNEL, VAL_SIZE)
ae_model = autoencoder.model1()
autoencoder.train(ae_model, lr, lossFunc, batchSize, epochs)
autoencoder.saveModel(weight_dir, ds_name, model_name, loss_type, ds_type)
# Out:
# #All images:  39209
# Train image set shape:  (31367, 48, 48, 3) Validation image set shape:  (7842, 48, 48, 3)
# 2022-10-24 01:01:25.124002: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 01:01:25.130816: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 01:01:25.131053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
weight_file0_1_2_3_4_5 = "/home/can/thesis/ae_weights/0_1_2_3_4_5fullmodel1mse.h5"
ae0_1_2_3_4_5 = ae.autoEncoder()
model0_1_2_3_4_5 = ae0_1_2_3_4_5.loadModel(weight_file0_1_2_3_4_5)
test_path1 = "/home/can/thesis/gtsrb/damaged_signs/1/dmg/"
ae0_1_2_3_4_5.showResults(7, test_path1, model0_1_2_3_4_5, "ALL")
# Out:
# 1/1 [==============================] - 0s 293ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file0_1_2_3_4_5 = "/home/can/thesis/ae_weights/0_1_2_3_4_5fullmodel1mse.h5"
ae0_1_2_3_4_5 = ae.autoEncoder()
model0_1_2_3_4_5 = ae0_1_2_3_4_5.loadModel(weight_file0_1_2_3_4_5)
test_path1 = "/home/can/thesis/gtsrb/damaged_signs/5/"
ae0_1_2_3_4_5.showResults(7, test_path1, model0_1_2_3_4_5, "ALL")
# Out:
# Destructor called, Employee deleted.
# 20/20 [==============================] - 0s 8ms/step

# %%
import ae
import tensorflow as tf
from tensorflow.keras.losses import MeanSquaredError
from time import sleep

weight_file_cropped_all = "/home/can/thesis/ae_weights/cropped_allfullmodel1mse.h5"
ae_cropped_all = ae.autoEncoder()
model_cropped_all= ae_cropped_all.loadModel(weight_file_cropped_all)
test_path1 = "/home/can/thesis/gtsrb/damaged_signs/1/dmg/"
ae_cropped_all.showResults(7, test_path1, model_cropped_all, "ALL")
# Out:
# 2022-10-26 01:07:51.062585: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-26 01:07:51.498598: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-26 01:07:52.860522: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:/home/can/thesis_ws/devel/lib:/home/can/bfmc_ws/devel/lib:/opt/ros/noetic/lib
# ...
