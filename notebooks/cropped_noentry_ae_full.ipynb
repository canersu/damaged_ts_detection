# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

import os
# Out:
# 2022-10-03 00:31:24.581589: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-03 00:31:24.781753: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-03 00:31:25.500425: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/can/.local/lib/python3.8/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2022-10-03 00:31:25.500529: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/can/.local/lib/python3.8/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2022-10-03 00:31:25.500537: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
BASE_PATH = '../gtsrb/'
TRAIN_PATH = BASE_PATH + 'cropped_train/17/'


data = []
labels = []

# NUM_CLASSES = len(os.listdir(TRAIN_PATH))
IMG_HEIGHT = 48
IMG_WIDTH = 48
IMG_CHAN = 3
# print("#classes: "+str(NUM_CLASSES))
img_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHAN)

# NUM_CATEGORIES = len(os.listdir(TRAIN_PATH))
#print("#categories: "+str(NUM_CATEGORIES))
#for category in range(NUM_CLASSES):
# each_class = 0
ts_noentry = os.path.join(TRAIN_PATH)
for img in os.listdir(ts_noentry):
    image = Image.open(os.path.join(ts_noentry, img))
    image = image.resize((IMG_HEIGHT,IMG_WIDTH))
    image = np.array(image)
    image = image/255.0
    data.append(image)

# %%
# Convert lists to NumPy arrays
data = np.array(data)

img_train, img_val = train_test_split(data,test_size=0.2, random_state=16)
print(img_train.shape, img_val.shape)
# Out:
# (888, 48, 48, 3) (222, 48, 48, 3)

# %%
ae = tf.keras.models.Sequential()
ae.add(tf.keras.layers.Conv2D(filters=8, kernel_size=(3,3), activation='relu', input_shape=img_shape))
ae.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu'))
ae.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
ae.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
ae.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
ae.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
ae.add(tf.keras.layers.Flatten())
ae.add(tf.keras.layers.Dense(1024, activation='relu'))
ae.add(tf.keras.layers.Dense(256, activation='relu'))
ae.add(tf.keras.layers.Dense(1024, activation='relu'))
ae.add(tf.keras.layers.Dense(5184, activation='relu'))
ae.add(tf.keras.layers.Reshape((9, 9, 64)))
ae.add(tf.keras.layers.UpSampling2D(size=(2, 2)))
ae.add(tf.keras.layers.Conv2DTranspose(filters=64, kernel_size=(3, 3), activation='relu'))
ae.add(tf.keras.layers.Conv2DTranspose(filters=32, kernel_size=(3, 3), activation='relu'))
ae.add(tf.keras.layers.UpSampling2D(size=(2, 2)))
ae.add(tf.keras.layers.Conv2DTranspose(filters=16, kernel_size=(3,3), activation='relu'))
ae.add(tf.keras.layers.Conv2DTranspose(filters=3, kernel_size = (3,3), activation = 'relu'))
ae.summary()
# Out:
# 2022-10-03 00:32:24.140345: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-03 00:32:24.147338: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/can/.local/lib/python3.8/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2022-10-03 00:32:24.147361: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-10-03 00:32:24.148060: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 8)         224
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 16)        1168
#
#  max_pooling2d (MaxPooling2D  (None, 22, 22, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 9, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 5184)              0
#
#  dense (Dense)               (None, 1024)              5309440
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dense_2 (Dense)             (None, 1024)              263168
#
#  dense_3 (Dense)             (None, 5184)              5313600
#
#  reshape (Reshape)           (None, 9, 9, 64)          0
#
#  up_sampling2d (UpSampling2D  (None, 18, 18, 64)       0
#  )
#
#  conv2d_transpose (Conv2DTra  (None, 20, 20, 64)       36928
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 22, 22, 32)       18464
#  ranspose)
#
#  up_sampling2d_1 (UpSampling  (None, 44, 44, 32)       0
#  2D)
#
#  conv2d_transpose_2 (Conv2DT  (None, 46, 46, 16)       4624
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 48, 48, 3)        435
#  ranspose)
#
# =================================================================
# Total params: 11,233,587
# Trainable params: 11,233,587
# Non-trainable params: 0
# _________________________________________________________________

# %%
def SSIMLoss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred,1.0))

# %%
optimizer = tf.keras.optimizers.Adam(lr = 0.0005)
ae.compile(loss=SSIMLoss, optimizer=optimizer, metrics=['accuracy'])
history = ae.fit(img_train, img_train, batch_size=64, epochs=100, validation_data=(img_val, img_val))
# Out:
# Epoch 1/100
# /home/can/.local/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 14/14 [==============================] - 9s 557ms/step - loss: 0.7137 - accuracy: 0.1035 - val_loss: 0.5552 - val_accuracy: 0.1479
# Epoch 2/100
# 14/14 [==============================] - 7s 510ms/step - loss: 0.4649 - accuracy: 0.3057 - val_loss: 0.4165 - val_accuracy: 0.6404
# Epoch 3/100
# 14/14 [==============================] - 7s 501ms/step - loss: 0.3886 - accuracy: 0.6760 - val_loss: 0.3611 - val_accuracy: 0.6875
# Epoch 4/100
# 14/14 [==============================] - 7s 495ms/step - loss: 0.3310 - accuracy: 0.6970 - val_loss: 0.3154 - val_accuracy: 0.7038
# Epoch 5/100
# 14/14 [==============================] - 7s 522ms/step - loss: 0.2895 - accuracy: 0.7099 - val_loss: 0.2727 - val_accuracy: 0.7273
# Epoch 6/100
# 14/14 [==============================] - 7s 524ms/step - loss: 0.2546 - accuracy: 0.7218 - val_loss: 0.2403 - val_accuracy: 0.7334
# Epoch 7/100
# 14/14 [==============================] - 7s 524ms/step - loss: 0.2286 - accuracy: 0.7296 - val_loss: 0.2195 - val_accuracy: 0.7356
# Epoch 8/100
# 14/14 [==============================] - 7s 529ms/step - loss: 0.2080 - accuracy: 0.7360 - val_loss: 0.2007 - val_accuracy: 0.7487
# Epoch 9/100
# 14/14 [==============================] - 7s 534ms/step - loss: 0.1901 - accuracy: 0.7438 - val_loss: 0.1831 - val_accuracy: 0.7529
# Epoch 10/100
# 14/14 [==============================] - 7s 527ms/step - loss: 0.1765 - accuracy: 0.7519 - val_loss: 0.1745 - val_accuracy: 0.7638
# Epoch 11/100
# 14/14 [==============================] - 7s 500ms/step - loss: 0.1634 - accuracy: 0.7577 - val_loss: 0.1655 - val_accuracy: 0.7645
# Epoch 12/100
# 14/14 [==============================] - 7s 525ms/step - loss: 0.1524 - accuracy: 0.7633 - val_loss: 0.1563 - val_accuracy: 0.7681
# Epoch 13/100
# 14/14 [==============================] - 7s 505ms/step - loss: 0.1438 - accuracy: 0.7662 - val_loss: 0.1470 - val_accuracy: 0.7726
# Epoch 14/100
# 14/14 [==============================] - 7s 522ms/step - loss: 0.1358 - accuracy: 0.7715 - val_loss: 0.1423 - val_accuracy: 0.7747
# Epoch 15/100
# 14/14 [==============================] - 7s 498ms/step - loss: 0.1280 - accuracy: 0.7735 - val_loss: 0.1352 - val_accuracy: 0.7770
# Epoch 16/100
# 14/14 [==============================] - 6s 449ms/step - loss: 0.1210 - accuracy: 0.7765 - val_loss: 0.1309 - val_accuracy: 0.7791
# Epoch 17/100
# 14/14 [==============================] - 6s 440ms/step - loss: 0.1157 - accuracy: 0.7799 - val_loss: 0.1263 - val_accuracy: 0.7820
# Epoch 18/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.1100 - accuracy: 0.7837 - val_loss: 0.1218 - val_accuracy: 0.7798
# Epoch 19/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.1062 - accuracy: 0.7835 - val_loss: 0.1188 - val_accuracy: 0.7829
# Epoch 20/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.1018 - accuracy: 0.7870 - val_loss: 0.1156 - val_accuracy: 0.7861
# Epoch 21/100
# 14/14 [==============================] - 6s 433ms/step - loss: 0.0990 - accuracy: 0.7894 - val_loss: 0.1137 - val_accuracy: 0.7858
# Epoch 22/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0961 - accuracy: 0.7904 - val_loss: 0.1112 - val_accuracy: 0.7897
# Epoch 23/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0937 - accuracy: 0.7928 - val_loss: 0.1091 - val_accuracy: 0.7914
# Epoch 24/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0906 - accuracy: 0.7937 - val_loss: 0.1065 - val_accuracy: 0.7939
# Epoch 25/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0871 - accuracy: 0.7955 - val_loss: 0.1053 - val_accuracy: 0.7954
# Epoch 26/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0851 - accuracy: 0.7970 - val_loss: 0.1044 - val_accuracy: 0.7957
# Epoch 27/100
# 14/14 [==============================] - 6s 448ms/step - loss: 0.0833 - accuracy: 0.7970 - val_loss: 0.1036 - val_accuracy: 0.7993
# Epoch 28/100
# 14/14 [==============================] - 6s 433ms/step - loss: 0.0817 - accuracy: 0.7987 - val_loss: 0.1025 - val_accuracy: 0.7983
# Epoch 29/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0816 - accuracy: 0.8000 - val_loss: 0.1000 - val_accuracy: 0.7970
# Epoch 30/100
# 14/14 [==============================] - 6s 439ms/step - loss: 0.0788 - accuracy: 0.8001 - val_loss: 0.1010 - val_accuracy: 0.7998
# Epoch 31/100
# 14/14 [==============================] - 6s 432ms/step - loss: 0.0779 - accuracy: 0.7999 - val_loss: 0.0981 - val_accuracy: 0.7983
# Epoch 32/100
# 14/14 [==============================] - 6s 430ms/step - loss: 0.0750 - accuracy: 0.8022 - val_loss: 0.0966 - val_accuracy: 0.8003
# Epoch 33/100
# 14/14 [==============================] - 6s 440ms/step - loss: 0.0730 - accuracy: 0.8030 - val_loss: 0.0951 - val_accuracy: 0.7984
# Epoch 34/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0715 - accuracy: 0.8024 - val_loss: 0.0947 - val_accuracy: 0.8003
# Epoch 35/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0708 - accuracy: 0.8038 - val_loss: 0.0950 - val_accuracy: 0.7993
# Epoch 36/100
# 14/14 [==============================] - 6s 451ms/step - loss: 0.0698 - accuracy: 0.8041 - val_loss: 0.0941 - val_accuracy: 0.8010
# Epoch 37/100
# 14/14 [==============================] - 6s 438ms/step - loss: 0.0680 - accuracy: 0.8055 - val_loss: 0.0927 - val_accuracy: 0.8034
# Epoch 38/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0671 - accuracy: 0.8057 - val_loss: 0.0928 - val_accuracy: 0.8013
# Epoch 39/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0656 - accuracy: 0.8068 - val_loss: 0.0919 - val_accuracy: 0.8027
# Epoch 40/100
# 14/14 [==============================] - 6s 437ms/step - loss: 0.0649 - accuracy: 0.8067 - val_loss: 0.0914 - val_accuracy: 0.8041
# Epoch 41/100
# 14/14 [==============================] - 6s 439ms/step - loss: 0.0638 - accuracy: 0.8077 - val_loss: 0.0913 - val_accuracy: 0.8003
# Epoch 42/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0627 - accuracy: 0.8079 - val_loss: 0.0907 - val_accuracy: 0.8060
# Epoch 43/100
# 14/14 [==============================] - 6s 433ms/step - loss: 0.0615 - accuracy: 0.8098 - val_loss: 0.0895 - val_accuracy: 0.8051
# Epoch 44/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0616 - accuracy: 0.8092 - val_loss: 0.0907 - val_accuracy: 0.8073
# Epoch 45/100
# 14/14 [==============================] - 6s 439ms/step - loss: 0.0605 - accuracy: 0.8106 - val_loss: 0.0893 - val_accuracy: 0.8038
# Epoch 46/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0593 - accuracy: 0.8111 - val_loss: 0.0889 - val_accuracy: 0.8060
# Epoch 47/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0587 - accuracy: 0.8110 - val_loss: 0.0892 - val_accuracy: 0.8049
# Epoch 48/100
# 14/14 [==============================] - 6s 439ms/step - loss: 0.0584 - accuracy: 0.8117 - val_loss: 0.0908 - val_accuracy: 0.8093
# Epoch 49/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0577 - accuracy: 0.8118 - val_loss: 0.0893 - val_accuracy: 0.8071
# Epoch 50/100
# 14/14 [==============================] - 6s 431ms/step - loss: 0.0573 - accuracy: 0.8140 - val_loss: 0.0892 - val_accuracy: 0.8073
# Epoch 51/100
# 14/14 [==============================] - 6s 439ms/step - loss: 0.0562 - accuracy: 0.8141 - val_loss: 0.0874 - val_accuracy: 0.8090
# Epoch 52/100
# 14/14 [==============================] - 6s 437ms/step - loss: 0.0550 - accuracy: 0.8145 - val_loss: 0.0876 - val_accuracy: 0.8095
# Epoch 53/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0547 - accuracy: 0.8156 - val_loss: 0.0876 - val_accuracy: 0.8112
# Epoch 54/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0544 - accuracy: 0.8167 - val_loss: 0.0905 - val_accuracy: 0.8127
# Epoch 55/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0543 - accuracy: 0.8167 - val_loss: 0.0876 - val_accuracy: 0.8097
# Epoch 56/100
# 14/14 [==============================] - 6s 444ms/step - loss: 0.0535 - accuracy: 0.8161 - val_loss: 0.0880 - val_accuracy: 0.8114
# Epoch 57/100
# 14/14 [==============================] - 6s 433ms/step - loss: 0.0532 - accuracy: 0.8181 - val_loss: 0.0878 - val_accuracy: 0.8096
# Epoch 58/100
# 14/14 [==============================] - 6s 445ms/step - loss: 0.0528 - accuracy: 0.8177 - val_loss: 0.0874 - val_accuracy: 0.8130
# Epoch 59/100
# 14/14 [==============================] - 6s 438ms/step - loss: 0.0528 - accuracy: 0.8173 - val_loss: 0.0866 - val_accuracy: 0.8132
# Epoch 60/100
# 14/14 [==============================] - 6s 432ms/step - loss: 0.0516 - accuracy: 0.8194 - val_loss: 0.0868 - val_accuracy: 0.8101
# Epoch 61/100
# 14/14 [==============================] - 6s 433ms/step - loss: 0.0510 - accuracy: 0.8192 - val_loss: 0.0863 - val_accuracy: 0.8112
# Epoch 62/100
# 14/14 [==============================] - 6s 433ms/step - loss: 0.0497 - accuracy: 0.8201 - val_loss: 0.0872 - val_accuracy: 0.8118
# Epoch 63/100
# 14/14 [==============================] - 6s 437ms/step - loss: 0.0500 - accuracy: 0.8203 - val_loss: 0.0860 - val_accuracy: 0.8088
# Epoch 64/100
# 14/14 [==============================] - 6s 432ms/step - loss: 0.0493 - accuracy: 0.8206 - val_loss: 0.0866 - val_accuracy: 0.8157
# Epoch 65/100
# 14/14 [==============================] - 6s 433ms/step - loss: 0.0483 - accuracy: 0.8212 - val_loss: 0.0871 - val_accuracy: 0.8131
# Epoch 66/100
# 14/14 [==============================] - 6s 432ms/step - loss: 0.0483 - accuracy: 0.8217 - val_loss: 0.0855 - val_accuracy: 0.8127
# Epoch 67/100
# 14/14 [==============================] - 6s 438ms/step - loss: 0.0478 - accuracy: 0.8218 - val_loss: 0.0857 - val_accuracy: 0.8154
# Epoch 68/100
# 14/14 [==============================] - 6s 433ms/step - loss: 0.0468 - accuracy: 0.8227 - val_loss: 0.0856 - val_accuracy: 0.8136
# Epoch 69/100
# 14/14 [==============================] - 6s 430ms/step - loss: 0.0459 - accuracy: 0.8238 - val_loss: 0.0847 - val_accuracy: 0.8155
# Epoch 70/100
# 14/14 [==============================] - 6s 431ms/step - loss: 0.0451 - accuracy: 0.8239 - val_loss: 0.0847 - val_accuracy: 0.8129
# Epoch 71/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0447 - accuracy: 0.8238 - val_loss: 0.0851 - val_accuracy: 0.8148
# Epoch 72/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0447 - accuracy: 0.8247 - val_loss: 0.0854 - val_accuracy: 0.8175
# Epoch 73/100
# 14/14 [==============================] - 6s 432ms/step - loss: 0.0442 - accuracy: 0.8253 - val_loss: 0.0850 - val_accuracy: 0.8170
# Epoch 74/100
# 14/14 [==============================] - 6s 437ms/step - loss: 0.0437 - accuracy: 0.8249 - val_loss: 0.0855 - val_accuracy: 0.8179
# Epoch 75/100
# 14/14 [==============================] - 6s 432ms/step - loss: 0.0433 - accuracy: 0.8260 - val_loss: 0.0844 - val_accuracy: 0.8178
# Epoch 76/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0427 - accuracy: 0.8263 - val_loss: 0.0845 - val_accuracy: 0.8165
# Epoch 77/100
# 14/14 [==============================] - 6s 443ms/step - loss: 0.0425 - accuracy: 0.8266 - val_loss: 0.0848 - val_accuracy: 0.8177
# Epoch 78/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0423 - accuracy: 0.8276 - val_loss: 0.0847 - val_accuracy: 0.8167
# Epoch 79/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0419 - accuracy: 0.8276 - val_loss: 0.0845 - val_accuracy: 0.8181
# Epoch 80/100
# 14/14 [==============================] - 6s 432ms/step - loss: 0.0417 - accuracy: 0.8281 - val_loss: 0.0848 - val_accuracy: 0.8142
# Epoch 81/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0416 - accuracy: 0.8276 - val_loss: 0.0847 - val_accuracy: 0.8187
# Epoch 82/100
# 14/14 [==============================] - 6s 441ms/step - loss: 0.0416 - accuracy: 0.8286 - val_loss: 0.0853 - val_accuracy: 0.8171
# Epoch 83/100
# 14/14 [==============================] - 6s 433ms/step - loss: 0.0411 - accuracy: 0.8282 - val_loss: 0.0848 - val_accuracy: 0.8202
# Epoch 84/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0410 - accuracy: 0.8297 - val_loss: 0.0859 - val_accuracy: 0.8152
# Epoch 85/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0415 - accuracy: 0.8291 - val_loss: 0.0853 - val_accuracy: 0.8176
# Epoch 86/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0409 - accuracy: 0.8286 - val_loss: 0.0852 - val_accuracy: 0.8206
# Epoch 87/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0407 - accuracy: 0.8301 - val_loss: 0.0851 - val_accuracy: 0.8197
# Epoch 88/100
# 14/14 [==============================] - 6s 433ms/step - loss: 0.0398 - accuracy: 0.8307 - val_loss: 0.0850 - val_accuracy: 0.8204
# Epoch 89/100
# 14/14 [==============================] - 6s 437ms/step - loss: 0.0394 - accuracy: 0.8311 - val_loss: 0.0854 - val_accuracy: 0.8211
# Epoch 90/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0392 - accuracy: 0.8319 - val_loss: 0.0845 - val_accuracy: 0.8173
# Epoch 91/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0386 - accuracy: 0.8315 - val_loss: 0.0842 - val_accuracy: 0.8202
# Epoch 92/100
# 14/14 [==============================] - 6s 434ms/step - loss: 0.0382 - accuracy: 0.8319 - val_loss: 0.0842 - val_accuracy: 0.8218
# Epoch 93/100
# 14/14 [==============================] - 6s 438ms/step - loss: 0.0389 - accuracy: 0.8320 - val_loss: 0.0858 - val_accuracy: 0.8194
# Epoch 94/100
# 14/14 [==============================] - 6s 437ms/step - loss: 0.0399 - accuracy: 0.8324 - val_loss: 0.0855 - val_accuracy: 0.8204
# Epoch 95/100
# 14/14 [==============================] - 6s 436ms/step - loss: 0.0393 - accuracy: 0.8325 - val_loss: 0.0859 - val_accuracy: 0.8219
# Epoch 96/100
# 14/14 [==============================] - 6s 441ms/step - loss: 0.0387 - accuracy: 0.8324 - val_loss: 0.0853 - val_accuracy: 0.8195
# Epoch 97/100
# 14/14 [==============================] - 6s 437ms/step - loss: 0.0379 - accuracy: 0.8333 - val_loss: 0.0847 - val_accuracy: 0.8192
# Epoch 98/100
# 14/14 [==============================] - 6s 437ms/step - loss: 0.0374 - accuracy: 0.8329 - val_loss: 0.0845 - val_accuracy: 0.8190
# Epoch 99/100
# 14/14 [==============================] - 6s 435ms/step - loss: 0.0368 - accuracy: 0.8339 - val_loss: 0.0843 - val_accuracy: 0.8204
# Epoch 100/100
# 14/14 [==============================] - 6s 439ms/step - loss: 0.0363 - accuracy: 0.8342 - val_loss: 0.0848 - val_accuracy: 0.8209

# %%
ae.save("autoencoder_cropped_noentry_full_ds_V1.h5")

# %%
test_data = []
TEST_PATH = BASE_PATH + 'damaged_noentry/web_imgs/'
test_noentry = os.path.join(TEST_PATH)
for img in os.listdir(test_noentry):
    image = Image.open(os.path.join(test_noentry, img)).convert('RGB')
    image = image.resize((IMG_HEIGHT,IMG_WIDTH))
    image = np.array(image)
    image = image/255.0
    test_data.append(image)

test_data = np.array(test_data)            
gen = ae.predict(test_data)
# Out:
# 1/1 [==============================] - 0s 181ms/step

# %%
tensor_val = tf.convert_to_tensor(img_val, dtype=tf.float32)
tensor_test = tf.convert_to_tensor(test_data, dtype=tf.float32)

# %%
decoded_imgs= ae.predict(img_val)
plt.figure(figsize=(20, 14), dpi=100)
plt.subplots_adjust( wspace=0.1, hspace=0.5)
plt_a=1
n=5
for i in range(n):
    # Original training dataset vs Original training
    ax = plt.subplot(3, n, plt_a   )
    plt.imshow(img_val[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)
    value_a = SSIMLoss(img_val[i], img_val[i])
    ax.set_title("Original Image")
    label = 'SSIM Loss value: {:.3f}'
    ax.set_xlabel(label.format(value_a) )
    
    # Reconstructed good data  vs Original training data
    ax = plt.subplot(3, n, plt_a + n )
    plt.imshow(decoded_imgs[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)    
    value_a = SSIMLoss(tensor_val[i], decoded_imgs[i])
    ax.set_title("Reconstructed Image")
    label = 'SSIM Loss value: {:.3f}'
    ax.set_xlabel(label.format(value_a) )

    # Reconstructed anomalous data  vs Original training data
    ax = plt.subplot(3, n, plt_a + 2*n)
    plt.imshow(test_data[i].reshape(48,48,3))
    #plt.imshow(decoded_imgs[i+4].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)
    value = SSIMLoss(tensor_test[i], decoded_imgs[i])
    #value = SSIMLoss(decoded_imgs[i+4], decoded_imgs[i])
    label = 'SSIM Loss value: {:.3f}'
    ax.set_title("Anamolus Image " )
    ax.set_xlabel(label.format(value) )
    plt_a+=1
plt.show()
# Out:
# 7/7 [==============================] - 0s 39ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for i in range(len(gen)):
    avg_err = 0.0
    for j in range(len(tensor_val)):
        value_a = SSIMLoss(gen[i], decoded_imgs[j])
        avg_err += value_a/len(tensor_val)
    print(avg_err)
# Out:
# tf.Tensor(0.917984, shape=(), dtype=float32)
# tf.Tensor(0.63852304, shape=(), dtype=float32)
# tf.Tensor(0.8134334, shape=(), dtype=float32)
# tf.Tensor(0.6546037, shape=(), dtype=float32)
# tf.Tensor(0.5858671, shape=(), dtype=float32)

# %%
for i in range(len(gen)):
    avg_err = 0.0
    for j in range(len(tensor_val)):
        value_a = SSIMLoss(tensor_test[i], decoded_imgs[j])
        avg_err += value_a/len(tensor_val)
    print(avg_err)
# Out:
# tf.Tensor(0.97187245, shape=(), dtype=float32)
# tf.Tensor(0.69418794, shape=(), dtype=float32)
# tf.Tensor(0.89348525, shape=(), dtype=float32)
# tf.Tensor(0.838787, shape=(), dtype=float32)
# tf.Tensor(0.76542044, shape=(), dtype=float32)

# %%
plt.figure(figsize=(20, 14), dpi=100)
plt.subplots_adjust( wspace=0.1, hspace=0.5)
plt_a=1
n=5
for i in range(n):
    # Original training dataset vs Original training
    ax = plt.subplot(3, n, plt_a   )
    plt.imshow(img_val[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)
    value_a = SSIMLoss(img_val[i], img_val[i])
    ax.set_title("Original Image")
    label = 'SSIM Loss value: {:.3f}'
    ax.set_xlabel(label.format(value_a) )
    
    # Reconstructed good data  vs Original training data
    ax = plt.subplot(3, n, plt_a + n )
    plt.imshow(decoded_imgs[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)    
    value_a = SSIMLoss(tensor_val[i], decoded_imgs[i])
    ax.set_title("Reconstructed Image")
    label = 'SSIM Loss value: {:.3f}'
    ax.set_xlabel(label.format(value_a) )

    plt_a+=1
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(20, 14), dpi=100)
plt.subplots_adjust( wspace=0.1, hspace=0.5)
plt_a=1
n=5
for i in range(n):
    # Original training dataset vs Original training
    ax = plt.subplot(3, n, plt_a   )
    plt.imshow(test_data[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)
    # value_a = SSIMLoss(img_val[i], img_val[i])
    ax.set_title("Original Image")
    # label = 'SSIM Loss value: {:.3f}'
    # ax.set_xlabel(label.format(value_a) )
    
    # Reconstructed good data  vs Original training data
    ax = plt.subplot(3, n, plt_a + n )
    plt.imshow(gen[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)    
    value_a = SSIMLoss(tensor_test[i], gen[i])
    ax.set_title("Reconstructed Image")
    label = 'SSIM Loss value: {:.3f}'
    ax.set_xlabel(label.format(value_a) )

    plt_a+=1
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
