# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

import os
# Out:
# 2022-10-06 18:31:38.103504: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-06 18:31:38.252121: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-06 18:31:38.873942: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/can/.local/lib/python3.8/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2022-10-06 18:31:38.874027: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/can/.local/lib/python3.8/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2022-10-06 18:31:38.874035: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
BASE_PATH = '../gtsrb/'
TRAIN_PATH = BASE_PATH + 'cropped_healthy_noentry/'


data = []
labels = []

# NUM_CLASSES = len(os.listdir(TRAIN_PATH))
IMG_HEIGHT = 48
IMG_WIDTH = 48
IMG_CHAN = 3
# print("#classes: "+str(NUM_CLASSES))
img_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHAN)

# NUM_CATEGORIES = len(os.listdir(TRAIN_PATH))
#print("#categories: "+str(NUM_CATEGORIES))
#for category in range(NUM_CLASSES):
# each_class = 0
ts_noentry = os.path.join(TRAIN_PATH)
for img in os.listdir(ts_noentry):
    image = Image.open(os.path.join(ts_noentry, img))
    image = image.resize((IMG_HEIGHT,IMG_WIDTH))
    image = np.array(image)
    image = image/255.0
    data.append(image)

# %%
# Convert lists to NumPy arrays
data = np.array(data)

img_train, img_val = train_test_split(data,test_size=0.2, random_state=16)
print("#Train image set shape: ", img_train.shape, "#Validation image set shape: ", img_val.shape)
# Out:
# #Train image set shape:  (476, 48, 48, 3) #Validation image set shape:  (120, 48, 48, 3)

# %%
type(img_shape)
# Out:
# tuple

# %%
ae = tf.keras.models.Sequential()
ae.add(tf.keras.layers.Conv2D(filters=8, kernel_size=(3,3), activation='relu', input_shape=img_shape))
ae.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu'))
ae.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
ae.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
ae.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
ae.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
ae.add(tf.keras.layers.Flatten())
ae.add(tf.keras.layers.Dense(1024, activation='relu'))
ae.add(tf.keras.layers.Dense(256, activation='relu'))
ae.add(tf.keras.layers.Dense(1024, activation='relu'))
ae.add(tf.keras.layers.Dense(5184, activation='relu'))
ae.add(tf.keras.layers.Reshape((9, 9, 64)))
ae.add(tf.keras.layers.UpSampling2D(size=(2, 2)))
ae.add(tf.keras.layers.Conv2DTranspose(filters=64, kernel_size=(3, 3), activation='relu'))
ae.add(tf.keras.layers.Conv2DTranspose(filters=32, kernel_size=(3, 3), activation='relu'))
ae.add(tf.keras.layers.UpSampling2D(size=(2, 2)))
ae.add(tf.keras.layers.Conv2DTranspose(filters=16, kernel_size=(3,3), activation='relu'))
ae.add(tf.keras.layers.Conv2DTranspose(filters=3, kernel_size = (3,3), activation = 'relu'))
ae.summary()
# Out:
# 2022-10-02 23:35:34.839341: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-02 23:35:34.845213: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/can/.local/lib/python3.8/site-packages/cv2/../../lib64:/usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2022-10-02 23:35:34.845234: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-10-02 23:35:34.846379: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 8)         224
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 16)        1168
#
#  max_pooling2d (MaxPooling2D  (None, 22, 22, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 9, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 5184)              0
#
#  dense (Dense)               (None, 1024)              5309440
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dense_2 (Dense)             (None, 1024)              263168
#
#  dense_3 (Dense)             (None, 5184)              5313600
#
#  reshape (Reshape)           (None, 9, 9, 64)          0
#
#  up_sampling2d (UpSampling2D  (None, 18, 18, 64)       0
#  )
#
#  conv2d_transpose (Conv2DTra  (None, 20, 20, 64)       36928
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 22, 22, 32)       18464
#  ranspose)
#
#  up_sampling2d_1 (UpSampling  (None, 44, 44, 32)       0
#  2D)
#
#  conv2d_transpose_2 (Conv2DT  (None, 46, 46, 16)       4624
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 48, 48, 3)        435
#  ranspose)
#
# =================================================================
# Total params: 11,233,587
# Trainable params: 11,233,587
# Non-trainable params: 0
# _________________________________________________________________

# %%
def SSIMLoss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred,1.0))

# %%
optimizer = tf.keras.optimizers.Adam(lr = 0.0005)
ae.compile(loss=SSIMLoss, optimizer=optimizer, metrics=['accuracy'])
history = ae.fit(img_train, img_train, batch_size=64, epochs=100, validation_data=(img_val, img_val))
# Out:
# Epoch 1/100
# /home/can/.local/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 8/8 [==============================] - 6s 530ms/step - loss: 0.9280 - accuracy: 0.1149 - val_loss: 0.8247 - val_accuracy: 0.0542
# Epoch 2/100
# 8/8 [==============================] - 4s 462ms/step - loss: 0.7729 - accuracy: 0.0561 - val_loss: 0.6685 - val_accuracy: 0.0741
# Epoch 3/100
# 8/8 [==============================] - 4s 464ms/step - loss: 0.6426 - accuracy: 0.1014 - val_loss: 0.6191 - val_accuracy: 0.1048
# Epoch 4/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.6104 - accuracy: 0.0935 - val_loss: 0.5853 - val_accuracy: 0.0774
# Epoch 5/100
# 8/8 [==============================] - 4s 463ms/step - loss: 0.5595 - accuracy: 0.0933 - val_loss: 0.5151 - val_accuracy: 0.1199
# Epoch 6/100
# 8/8 [==============================] - 4s 471ms/step - loss: 0.4867 - accuracy: 0.3554 - val_loss: 0.4621 - val_accuracy: 0.7641
# Epoch 7/100
# 8/8 [==============================] - 4s 470ms/step - loss: 0.4407 - accuracy: 0.7879 - val_loss: 0.4201 - val_accuracy: 0.7992
# Epoch 8/100
# 8/8 [==============================] - 4s 470ms/step - loss: 0.3963 - accuracy: 0.7833 - val_loss: 0.3725 - val_accuracy: 0.7545
# Epoch 9/100
# 8/8 [==============================] - 4s 463ms/step - loss: 0.3461 - accuracy: 0.7302 - val_loss: 0.3145 - val_accuracy: 0.7459
# Epoch 10/100
# 8/8 [==============================] - 4s 461ms/step - loss: 0.3058 - accuracy: 0.7553 - val_loss: 0.2895 - val_accuracy: 0.7717
# Epoch 11/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.2786 - accuracy: 0.7618 - val_loss: 0.2693 - val_accuracy: 0.7658
# Epoch 12/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.2569 - accuracy: 0.7646 - val_loss: 0.2484 - val_accuracy: 0.7664
# Epoch 13/100
# 8/8 [==============================] - 4s 476ms/step - loss: 0.2384 - accuracy: 0.7654 - val_loss: 0.2362 - val_accuracy: 0.7631
# Epoch 14/100
# 8/8 [==============================] - 4s 459ms/step - loss: 0.2226 - accuracy: 0.7650 - val_loss: 0.2210 - val_accuracy: 0.7620
# Epoch 15/100
# 8/8 [==============================] - 4s 461ms/step - loss: 0.2090 - accuracy: 0.7703 - val_loss: 0.2089 - val_accuracy: 0.7683
# Epoch 16/100
# 8/8 [==============================] - 4s 460ms/step - loss: 0.1952 - accuracy: 0.7729 - val_loss: 0.1979 - val_accuracy: 0.7708
# Epoch 17/100
# 8/8 [==============================] - 4s 463ms/step - loss: 0.1842 - accuracy: 0.7744 - val_loss: 0.1863 - val_accuracy: 0.7823
# Epoch 18/100
# 8/8 [==============================] - 4s 479ms/step - loss: 0.1713 - accuracy: 0.7832 - val_loss: 0.1772 - val_accuracy: 0.7815
# Epoch 19/100
# 8/8 [==============================] - 4s 462ms/step - loss: 0.1623 - accuracy: 0.7801 - val_loss: 0.1722 - val_accuracy: 0.7810
# Epoch 20/100
# 8/8 [==============================] - 4s 464ms/step - loss: 0.1563 - accuracy: 0.7847 - val_loss: 0.1660 - val_accuracy: 0.7790
# Epoch 21/100
# 8/8 [==============================] - 4s 471ms/step - loss: 0.1478 - accuracy: 0.7837 - val_loss: 0.1595 - val_accuracy: 0.7874
# Epoch 22/100
# 8/8 [==============================] - 4s 464ms/step - loss: 0.1407 - accuracy: 0.7827 - val_loss: 0.1552 - val_accuracy: 0.7832
# Epoch 23/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.1363 - accuracy: 0.7864 - val_loss: 0.1506 - val_accuracy: 0.7846
# Epoch 24/100
# 8/8 [==============================] - 4s 473ms/step - loss: 0.1315 - accuracy: 0.7856 - val_loss: 0.1469 - val_accuracy: 0.7841
# Epoch 25/100
# 8/8 [==============================] - 4s 457ms/step - loss: 0.1271 - accuracy: 0.7865 - val_loss: 0.1444 - val_accuracy: 0.7872
# Epoch 26/100
# 8/8 [==============================] - 4s 468ms/step - loss: 0.1223 - accuracy: 0.7884 - val_loss: 0.1422 - val_accuracy: 0.7864
# Epoch 27/100
# 8/8 [==============================] - 4s 484ms/step - loss: 0.1186 - accuracy: 0.7869 - val_loss: 0.1373 - val_accuracy: 0.7891
# Epoch 28/100
# 8/8 [==============================] - 4s 472ms/step - loss: 0.1146 - accuracy: 0.7893 - val_loss: 0.1361 - val_accuracy: 0.7833
# Epoch 29/100
# 8/8 [==============================] - 4s 474ms/step - loss: 0.1121 - accuracy: 0.7898 - val_loss: 0.1382 - val_accuracy: 0.7883
# Epoch 30/100
# 8/8 [==============================] - 4s 471ms/step - loss: 0.1094 - accuracy: 0.7887 - val_loss: 0.1333 - val_accuracy: 0.7870
# Epoch 31/100
# 8/8 [==============================] - 4s 478ms/step - loss: 0.1074 - accuracy: 0.7909 - val_loss: 0.1315 - val_accuracy: 0.7886
# Epoch 32/100
# 8/8 [==============================] - 4s 470ms/step - loss: 0.1035 - accuracy: 0.7908 - val_loss: 0.1281 - val_accuracy: 0.7902
# Epoch 33/100
# 8/8 [==============================] - 4s 462ms/step - loss: 0.1000 - accuracy: 0.7921 - val_loss: 0.1253 - val_accuracy: 0.7885
# Epoch 34/100
# 8/8 [==============================] - 4s 465ms/step - loss: 0.0973 - accuracy: 0.7927 - val_loss: 0.1245 - val_accuracy: 0.7915
# Epoch 35/100
# 8/8 [==============================] - 4s 468ms/step - loss: 0.0946 - accuracy: 0.7933 - val_loss: 0.1227 - val_accuracy: 0.7922
# Epoch 36/100
# 8/8 [==============================] - 4s 465ms/step - loss: 0.0927 - accuracy: 0.7932 - val_loss: 0.1213 - val_accuracy: 0.7898
# Epoch 37/100
# 8/8 [==============================] - 4s 469ms/step - loss: 0.0911 - accuracy: 0.7940 - val_loss: 0.1218 - val_accuracy: 0.7905
# Epoch 38/100
# 8/8 [==============================] - 4s 467ms/step - loss: 0.0902 - accuracy: 0.7947 - val_loss: 0.1214 - val_accuracy: 0.7943
# Epoch 39/100
# 8/8 [==============================] - 4s 468ms/step - loss: 0.0897 - accuracy: 0.7955 - val_loss: 0.1219 - val_accuracy: 0.7900
# Epoch 40/100
# 8/8 [==============================] - 4s 467ms/step - loss: 0.0880 - accuracy: 0.7977 - val_loss: 0.1203 - val_accuracy: 0.7904
# Epoch 41/100
# 8/8 [==============================] - 4s 477ms/step - loss: 0.0860 - accuracy: 0.7958 - val_loss: 0.1170 - val_accuracy: 0.7924
# Epoch 42/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.0835 - accuracy: 0.7965 - val_loss: 0.1164 - val_accuracy: 0.7947
# Epoch 43/100
# 8/8 [==============================] - 4s 469ms/step - loss: 0.0817 - accuracy: 0.7997 - val_loss: 0.1159 - val_accuracy: 0.7945
# Epoch 44/100
# 8/8 [==============================] - 4s 464ms/step - loss: 0.0803 - accuracy: 0.7998 - val_loss: 0.1147 - val_accuracy: 0.7927
# Epoch 45/100
# 8/8 [==============================] - 4s 462ms/step - loss: 0.0792 - accuracy: 0.7990 - val_loss: 0.1155 - val_accuracy: 0.7960
# Epoch 46/100
# 8/8 [==============================] - 4s 465ms/step - loss: 0.0784 - accuracy: 0.7991 - val_loss: 0.1143 - val_accuracy: 0.7975
# Epoch 47/100
# 8/8 [==============================] - 4s 467ms/step - loss: 0.0771 - accuracy: 0.8005 - val_loss: 0.1148 - val_accuracy: 0.8002
# Epoch 48/100
# 8/8 [==============================] - 4s 473ms/step - loss: 0.0760 - accuracy: 0.8025 - val_loss: 0.1140 - val_accuracy: 0.8010
# Epoch 49/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.0749 - accuracy: 0.8018 - val_loss: 0.1136 - val_accuracy: 0.7990
# Epoch 50/100
# 8/8 [==============================] - 4s 471ms/step - loss: 0.0735 - accuracy: 0.8040 - val_loss: 0.1127 - val_accuracy: 0.7976
# Epoch 51/100
# 8/8 [==============================] - 4s 463ms/step - loss: 0.0728 - accuracy: 0.8032 - val_loss: 0.1133 - val_accuracy: 0.7972
# Epoch 52/100
# 8/8 [==============================] - 4s 465ms/step - loss: 0.0721 - accuracy: 0.8040 - val_loss: 0.1130 - val_accuracy: 0.8011
# Epoch 53/100
# 8/8 [==============================] - 4s 468ms/step - loss: 0.0703 - accuracy: 0.8059 - val_loss: 0.1110 - val_accuracy: 0.7949
# Epoch 54/100
# 8/8 [==============================] - 4s 474ms/step - loss: 0.0694 - accuracy: 0.8039 - val_loss: 0.1104 - val_accuracy: 0.7987
# Epoch 55/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.0682 - accuracy: 0.8068 - val_loss: 0.1118 - val_accuracy: 0.7981
# Epoch 56/100
# 8/8 [==============================] - 4s 463ms/step - loss: 0.0679 - accuracy: 0.8065 - val_loss: 0.1106 - val_accuracy: 0.7969
# Epoch 57/100
# 8/8 [==============================] - 4s 464ms/step - loss: 0.0668 - accuracy: 0.8058 - val_loss: 0.1114 - val_accuracy: 0.7998
# Epoch 58/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.0675 - accuracy: 0.8066 - val_loss: 0.1122 - val_accuracy: 0.8022
# Epoch 59/100
# 8/8 [==============================] - 4s 464ms/step - loss: 0.0673 - accuracy: 0.8077 - val_loss: 0.1112 - val_accuracy: 0.7975
# Epoch 60/100
# 8/8 [==============================] - 4s 478ms/step - loss: 0.0658 - accuracy: 0.8084 - val_loss: 0.1108 - val_accuracy: 0.8032
# Epoch 61/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.0638 - accuracy: 0.8086 - val_loss: 0.1092 - val_accuracy: 0.8067
# Epoch 62/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.0627 - accuracy: 0.8096 - val_loss: 0.1088 - val_accuracy: 0.8014
# Epoch 63/100
# 8/8 [==============================] - 4s 464ms/step - loss: 0.0616 - accuracy: 0.8095 - val_loss: 0.1095 - val_accuracy: 0.8004
# Epoch 64/100
# 8/8 [==============================] - 4s 468ms/step - loss: 0.0614 - accuracy: 0.8095 - val_loss: 0.1116 - val_accuracy: 0.8031
# Epoch 65/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.0618 - accuracy: 0.8109 - val_loss: 0.1091 - val_accuracy: 0.8014
# Epoch 66/100
# 8/8 [==============================] - 4s 478ms/step - loss: 0.0600 - accuracy: 0.8095 - val_loss: 0.1087 - val_accuracy: 0.8046
# Epoch 67/100
# 8/8 [==============================] - 4s 469ms/step - loss: 0.0590 - accuracy: 0.8117 - val_loss: 0.1084 - val_accuracy: 0.8007
# Epoch 68/100
# 8/8 [==============================] - 4s 463ms/step - loss: 0.0586 - accuracy: 0.8102 - val_loss: 0.1083 - val_accuracy: 0.8014
# Epoch 69/100
# 8/8 [==============================] - 4s 465ms/step - loss: 0.0581 - accuracy: 0.8125 - val_loss: 0.1088 - val_accuracy: 0.8039
# Epoch 70/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.0578 - accuracy: 0.8120 - val_loss: 0.1078 - val_accuracy: 0.8016
# Epoch 71/100
# 8/8 [==============================] - 4s 469ms/step - loss: 0.0571 - accuracy: 0.8123 - val_loss: 0.1095 - val_accuracy: 0.8033
# Epoch 72/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.0565 - accuracy: 0.8123 - val_loss: 0.1088 - val_accuracy: 0.8069
# Epoch 73/100
# 8/8 [==============================] - 4s 473ms/step - loss: 0.0556 - accuracy: 0.8125 - val_loss: 0.1091 - val_accuracy: 0.8056
# Epoch 74/100
# 8/8 [==============================] - 4s 464ms/step - loss: 0.0553 - accuracy: 0.8127 - val_loss: 0.1081 - val_accuracy: 0.8041
# Epoch 75/100
# 8/8 [==============================] - 4s 467ms/step - loss: 0.0549 - accuracy: 0.8143 - val_loss: 0.1093 - val_accuracy: 0.8062
# Epoch 76/100
# 8/8 [==============================] - 4s 466ms/step - loss: 0.0544 - accuracy: 0.8140 - val_loss: 0.1080 - val_accuracy: 0.8053
# Epoch 77/100
# 8/8 [==============================] - 4s 470ms/step - loss: 0.0544 - accuracy: 0.8138 - val_loss: 0.1089 - val_accuracy: 0.8047
# Epoch 78/100
# 8/8 [==============================] - 4s 464ms/step - loss: 0.0544 - accuracy: 0.8145 - val_loss: 0.1093 - val_accuracy: 0.8072
# Epoch 79/100
# 8/8 [==============================] - 4s 467ms/step - loss: 0.0545 - accuracy: 0.8146 - val_loss: 0.1100 - val_accuracy: 0.8096
# Epoch 80/100
# 8/8 [==============================] - 4s 462ms/step - loss: 0.0546 - accuracy: 0.8144 - val_loss: 0.1108 - val_accuracy: 0.8065
# Epoch 81/100
# 8/8 [==============================] - 4s 463ms/step - loss: 0.0554 - accuracy: 0.8161 - val_loss: 0.1114 - val_accuracy: 0.8006
# Epoch 82/100
# 8/8 [==============================] - 4s 464ms/step - loss: 0.0566 - accuracy: 0.8136 - val_loss: 0.1107 - val_accuracy: 0.8045
# Epoch 83/100
# 8/8 [==============================] - 4s 465ms/step - loss: 0.0546 - accuracy: 0.8165 - val_loss: 0.1106 - val_accuracy: 0.8073
# Epoch 84/100
# 8/8 [==============================] - 4s 468ms/step - loss: 0.0533 - accuracy: 0.8147 - val_loss: 0.1092 - val_accuracy: 0.8092
# Epoch 85/100
# 8/8 [==============================] - 4s 447ms/step - loss: 0.0518 - accuracy: 0.8168 - val_loss: 0.1075 - val_accuracy: 0.8087
# Epoch 86/100
# 8/8 [==============================] - 3s 422ms/step - loss: 0.0503 - accuracy: 0.8165 - val_loss: 0.1076 - val_accuracy: 0.8103
# Epoch 87/100
# 8/8 [==============================] - 3s 415ms/step - loss: 0.0490 - accuracy: 0.8195 - val_loss: 0.1069 - val_accuracy: 0.8084
# Epoch 88/100
# 8/8 [==============================] - 3s 415ms/step - loss: 0.0482 - accuracy: 0.8187 - val_loss: 0.1067 - val_accuracy: 0.8095
# Epoch 89/100
# 8/8 [==============================] - 3s 415ms/step - loss: 0.0477 - accuracy: 0.8187 - val_loss: 0.1074 - val_accuracy: 0.8095
# Epoch 90/100
# 8/8 [==============================] - 3s 413ms/step - loss: 0.0472 - accuracy: 0.8175 - val_loss: 0.1065 - val_accuracy: 0.8095
# Epoch 91/100
# 8/8 [==============================] - 4s 487ms/step - loss: 0.0468 - accuracy: 0.8206 - val_loss: 0.1080 - val_accuracy: 0.8109
# Epoch 92/100
# 8/8 [==============================] - 4s 465ms/step - loss: 0.0466 - accuracy: 0.8199 - val_loss: 0.1073 - val_accuracy: 0.8068
# Epoch 93/100
# 8/8 [==============================] - 4s 467ms/step - loss: 0.0464 - accuracy: 0.8195 - val_loss: 0.1076 - val_accuracy: 0.8087
# Epoch 94/100
# 8/8 [==============================] - 4s 471ms/step - loss: 0.0465 - accuracy: 0.8200 - val_loss: 0.1082 - val_accuracy: 0.8103
# Epoch 95/100
# 8/8 [==============================] - 4s 478ms/step - loss: 0.0459 - accuracy: 0.8203 - val_loss: 0.1074 - val_accuracy: 0.8117
# Epoch 96/100
# 8/8 [==============================] - 4s 467ms/step - loss: 0.0459 - accuracy: 0.8211 - val_loss: 0.1079 - val_accuracy: 0.8104
# Epoch 97/100
# 8/8 [==============================] - 4s 467ms/step - loss: 0.0454 - accuracy: 0.8221 - val_loss: 0.1078 - val_accuracy: 0.8106
# Epoch 98/100
# 8/8 [==============================] - 4s 465ms/step - loss: 0.0451 - accuracy: 0.8218 - val_loss: 0.1077 - val_accuracy: 0.8117
# Epoch 99/100
# 8/8 [==============================] - 4s 479ms/step - loss: 0.0450 - accuracy: 0.8234 - val_loss: 0.1075 - val_accuracy: 0.8102
# Epoch 100/100
# 8/8 [==============================] - 4s 467ms/step - loss: 0.0442 - accuracy: 0.8234 - val_loss: 0.1077 - val_accuracy: 0.8104

# %%
ae.save("autoencoder_cropped_noentry_V1.h5")

# %%
test_data = []
TEST_PATH = BASE_PATH + 'damaged_noentry/web_imgs/'
test_noentry = os.path.join(TEST_PATH)
for img in os.listdir(test_noentry):
    image = Image.open(os.path.join(test_noentry, img)).convert('RGB')
    image = image.resize((IMG_HEIGHT,IMG_WIDTH))
    image = np.array(image)
    image = image/255.0
    test_data.append(image)

test_data = np.array(test_data)            
gen = ae.predict(test_data)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
tensor_val = tf.convert_to_tensor(img_val, dtype=tf.float32)
tensor_test = tf.convert_to_tensor(test_data, dtype=tf.float32)

# %%
decoded_imgs= ae.predict(img_val)
plt.figure(figsize=(20, 14), dpi=100)
plt.subplots_adjust( wspace=0.1, hspace=0.5)
plt_a=1
n=5
for i in range(n):
    # Original training dataset vs Original training
    ax = plt.subplot(3, n, plt_a   )
    plt.imshow(img_val[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)
    value_a = SSIMLoss(img_val[i], img_val[i])
    ax.set_title("Original Image")
    label = 'SSIM Loss value: {:.3f}'
    ax.set_xlabel(label.format(value_a) )
    
    # Reconstructed good data  vs Original training data
    ax = plt.subplot(3, n, plt_a + n )
    plt.imshow(decoded_imgs[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)    
    value_a = SSIMLoss(tensor_val[i], decoded_imgs[i])
    ax.set_title("Reconstructed Image")
    label = 'SSIM Loss value: {:.3f}'
    ax.set_xlabel(label.format(value_a) )

    # Reconstructed anomalous data  vs Original training data
    ax = plt.subplot(3, n, plt_a + 2*n)
    plt.imshow(test_data[i].reshape(48,48,3))
    #plt.imshow(decoded_imgs[i+4].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)
    value = SSIMLoss(tensor_test[i], decoded_imgs[i])
    #value = SSIMLoss(decoded_imgs[i+4], decoded_imgs[i])
    label = 'SSIM Loss value: {:.3f}'
    ax.set_title("Anamolus Image " )
    ax.set_xlabel(label.format(value) )
    plt_a+=1
plt.show()
# Out:
# 4/4 [==============================] - 0s 49ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for i in range(len(gen)):
    avg_err = 0.0
    for j in range(len(tensor_val)):
        value_a = SSIMLoss(gen[i], decoded_imgs[j])
        avg_err += value_a/len(tensor_val)
    print(avg_err)
# Out:
# tf.Tensor(0.7568555, shape=(), dtype=float32)
# tf.Tensor(0.57744044, shape=(), dtype=float32)
# tf.Tensor(0.7934939, shape=(), dtype=float32)
# tf.Tensor(0.67895275, shape=(), dtype=float32)
# tf.Tensor(0.6393268, shape=(), dtype=float32)

# %%
for i in range(len(gen)):
    avg_err = 0.0
    for j in range(len(tensor_val)):
        value_a = SSIMLoss(tensor_test[i], decoded_imgs[j])
        avg_err += value_a/len(tensor_val)
    print(avg_err)
# Out:
# tf.Tensor(0.97758245, shape=(), dtype=float32)
# tf.Tensor(0.66347766, shape=(), dtype=float32)
# tf.Tensor(0.88554084, shape=(), dtype=float32)
# tf.Tensor(0.8187488, shape=(), dtype=float32)
# tf.Tensor(0.75324935, shape=(), dtype=float32)

# %%
for i in range(len(decoded_imgs)):
    avg_err = 0.0
    for j in range(len(tensor_val)):
        value_a = SSIMLoss(tensor_val[i], decoded_imgs[j])
        avg_err += value_a/len(tensor_val)
    print(avg_err)
# Out:
# tf.Tensor(0.5478437, shape=(), dtype=float32)
# tf.Tensor(0.60767823, shape=(), dtype=float32)
# tf.Tensor(0.57998776, shape=(), dtype=float32)
# tf.Tensor(0.57422125, shape=(), dtype=float32)
# tf.Tensor(0.6383793, shape=(), dtype=float32)
# tf.Tensor(0.60699695, shape=(), dtype=float32)
# tf.Tensor(0.8134138, shape=(), dtype=float32)
# tf.Tensor(0.5573131, shape=(), dtype=float32)
# tf.Tensor(0.48906314, shape=(), dtype=float32)
# tf.Tensor(0.51060086, shape=(), dtype=float32)
# tf.Tensor(0.5262778, shape=(), dtype=float32)
# tf.Tensor(0.54242134, shape=(), dtype=float32)
# tf.Tensor(0.6334824, shape=(), dtype=float32)
# tf.Tensor(0.6430192, shape=(), dtype=float32)
# tf.Tensor(0.5922607, shape=(), dtype=float32)
# tf.Tensor(0.60048336, shape=(), dtype=float32)
# tf.Tensor(0.5625569, shape=(), dtype=float32)
# tf.Tensor(0.62172556, shape=(), dtype=float32)
# tf.Tensor(0.5757039, shape=(), dtype=float32)
# tf.Tensor(0.61078334, shape=(), dtype=float32)
# tf.Tensor(0.560595, shape=(), dtype=float32)
# tf.Tensor(0.6046549, shape=(), dtype=float32)
# tf.Tensor(0.575317, shape=(), dtype=float32)
# tf.Tensor(0.6148697, shape=(), dtype=float32)
# tf.Tensor(0.69494486, shape=(), dtype=float32)
# tf.Tensor(0.6818995, shape=(), dtype=float32)
# tf.Tensor(0.667755, shape=(), dtype=float32)
# tf.Tensor(0.55638915, shape=(), dtype=float32)
# tf.Tensor(0.5632907, shape=(), dtype=float32)
# tf.Tensor(0.58714974, shape=(), dtype=float32)
# tf.Tensor(0.5845811, shape=(), dtype=float32)
# tf.Tensor(0.517567, shape=(), dtype=float32)
# tf.Tensor(0.74843353, shape=(), dtype=float32)
# tf.Tensor(0.57242703, shape=(), dtype=float32)
# tf.Tensor(0.5852688, shape=(), dtype=float32)
# tf.Tensor(0.59689337, shape=(), dtype=float32)
# tf.Tensor(0.6277083, shape=(), dtype=float32)
# tf.Tensor(0.5728893, shape=(), dtype=float32)
# tf.Tensor(0.49560827, shape=(), dtype=float32)
# tf.Tensor(0.5752202, shape=(), dtype=float32)
# tf.Tensor(0.55716425, shape=(), dtype=float32)
# tf.Tensor(0.5576933, shape=(), dtype=float32)
# tf.Tensor(0.597268, shape=(), dtype=float32)
# tf.Tensor(0.6258473, shape=(), dtype=float32)
# tf.Tensor(0.6301642, shape=(), dtype=float32)
# tf.Tensor(0.5825627, shape=(), dtype=float32)
# tf.Tensor(0.84508795, shape=(), dtype=float32)
# tf.Tensor(0.54287916, shape=(), dtype=float32)
# tf.Tensor(0.5521342, shape=(), dtype=float32)
# tf.Tensor(0.51827914, shape=(), dtype=float32)
# tf.Tensor(0.5164703, shape=(), dtype=float32)
# tf.Tensor(0.5227404, shape=(), dtype=float32)
# tf.Tensor(0.5149529, shape=(), dtype=float32)
# tf.Tensor(0.62924796, shape=(), dtype=float32)
# tf.Tensor(0.5575085, shape=(), dtype=float32)
# tf.Tensor(0.5955829, shape=(), dtype=float32)
# tf.Tensor(0.7189314, shape=(), dtype=float32)
# tf.Tensor(0.5133058, shape=(), dtype=float32)
# tf.Tensor(0.58505404, shape=(), dtype=float32)
# tf.Tensor(0.6851845, shape=(), dtype=float32)
# tf.Tensor(0.56370693, shape=(), dtype=float32)
# tf.Tensor(0.58843786, shape=(), dtype=float32)
# tf.Tensor(0.5031172, shape=(), dtype=float32)
# tf.Tensor(0.5587128, shape=(), dtype=float32)
# tf.Tensor(0.5791835, shape=(), dtype=float32)
# tf.Tensor(0.5347803, shape=(), dtype=float32)
# tf.Tensor(0.6120637, shape=(), dtype=float32)
# tf.Tensor(0.48992166, shape=(), dtype=float32)
# tf.Tensor(0.6168883, shape=(), dtype=float32)
# tf.Tensor(0.6184081, shape=(), dtype=float32)
# tf.Tensor(0.66615784, shape=(), dtype=float32)
# tf.Tensor(0.6462633, shape=(), dtype=float32)
# tf.Tensor(0.55433095, shape=(), dtype=float32)
# tf.Tensor(0.600892, shape=(), dtype=float32)
# tf.Tensor(0.5353561, shape=(), dtype=float32)
# tf.Tensor(0.49857807, shape=(), dtype=float32)
# tf.Tensor(0.69549775, shape=(), dtype=float32)
# tf.Tensor(0.6597251, shape=(), dtype=float32)
# tf.Tensor(0.52062124, shape=(), dtype=float32)
# tf.Tensor(0.5998511, shape=(), dtype=float32)
# tf.Tensor(0.7390047, shape=(), dtype=float32)
# tf.Tensor(0.58110356, shape=(), dtype=float32)
# tf.Tensor(0.5334727, shape=(), dtype=float32)
# tf.Tensor(0.6813817, shape=(), dtype=float32)
# tf.Tensor(0.62962544, shape=(), dtype=float32)
# tf.Tensor(0.6350689, shape=(), dtype=float32)
# tf.Tensor(0.6270916, shape=(), dtype=float32)
# tf.Tensor(0.5611767, shape=(), dtype=float32)
# tf.Tensor(0.6500493, shape=(), dtype=float32)
# tf.Tensor(0.5826436, shape=(), dtype=float32)
# tf.Tensor(0.62521946, shape=(), dtype=float32)
# tf.Tensor(0.51691467, shape=(), dtype=float32)
# tf.Tensor(0.575304, shape=(), dtype=float32)
# tf.Tensor(0.6414925, shape=(), dtype=float32)
# tf.Tensor(0.92386836, shape=(), dtype=float32)
# tf.Tensor(0.5154512, shape=(), dtype=float32)
# tf.Tensor(0.57336146, shape=(), dtype=float32)
# tf.Tensor(0.48701537, shape=(), dtype=float32)
# tf.Tensor(0.69155675, shape=(), dtype=float32)
# tf.Tensor(0.5305897, shape=(), dtype=float32)
# tf.Tensor(0.6741406, shape=(), dtype=float32)
# tf.Tensor(0.58826745, shape=(), dtype=float32)
# tf.Tensor(0.673904, shape=(), dtype=float32)
# tf.Tensor(0.5142509, shape=(), dtype=float32)
# tf.Tensor(0.5714777, shape=(), dtype=float32)
# tf.Tensor(0.56976104, shape=(), dtype=float32)
# tf.Tensor(0.6501268, shape=(), dtype=float32)
# tf.Tensor(0.5428983, shape=(), dtype=float32)
# tf.Tensor(0.72937775, shape=(), dtype=float32)
# tf.Tensor(0.5806823, shape=(), dtype=float32)
# tf.Tensor(0.62130535, shape=(), dtype=float32)
# tf.Tensor(0.51372695, shape=(), dtype=float32)
# tf.Tensor(0.61318094, shape=(), dtype=float32)
# tf.Tensor(0.5120176, shape=(), dtype=float32)
# tf.Tensor(0.56526387, shape=(), dtype=float32)
# tf.Tensor(0.6657877, shape=(), dtype=float32)
# tf.Tensor(0.58704144, shape=(), dtype=float32)
# tf.Tensor(0.5489171, shape=(), dtype=float32)
# tf.Tensor(0.63335544, shape=(), dtype=float32)
# tf.Tensor(0.5116484, shape=(), dtype=float32)

# %%
decoded_imgs= ae.predict(img_val)
plt.figure(figsize=(20, 14), dpi=100)
plt.subplots_adjust( wspace=0.1, hspace=0.5)
plt_a=1
n=5
for i in range(n):
    # Original training dataset vs Original training
    ax = plt.subplot(3, n, plt_a   )
    plt.imshow(img_val[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)
    value_a = SSIMLoss(img_val[i], img_val[i])
    ax.set_title("Original Image")
    label = 'SSIM Loss value: {:.3f}'
    ax.set_xlabel(label.format(value_a) )
    
    # Reconstructed good data  vs Original training data
    ax = plt.subplot(3, n, plt_a + n )
    plt.imshow(decoded_imgs[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)    
    value_a = SSIMLoss(tensor_val[i], decoded_imgs[i])
    ax.set_title("Reconstructed Image")
    label = 'SSIM Loss value: {:.3f}'
    ax.set_xlabel(label.format(value_a) )

    plt_a+=1
plt.show()
# Out:
# 4/4 [==============================] - 0s 39ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(20, 14), dpi=100)
plt.subplots_adjust( wspace=0.1, hspace=0.5)
plt_a=1
n=5
for i in range(n):
    # Original training dataset vs Original training
    ax = plt.subplot(3, n, plt_a   )
    plt.imshow(test_data[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)
    # value_a = SSIMLoss(img_val[i], img_val[i])
    ax.set_title("Original Image")
    # label = 'SSIM Loss value: {:.3f}'
    # ax.set_xlabel(label.format(value_a) )
    
    # Reconstructed good data  vs Original training data
    ax = plt.subplot(3, n, plt_a + n )
    plt.imshow(gen[i].reshape(48,48,3))
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(False)    
    value_a = SSIMLoss(tensor_test[i], gen[i])
    ax.set_title("Reconstructed Image")
    label = 'SSIM Loss value: {:.3f}'
    ax.set_xlabel(label.format(value_a) )

    plt_a+=1
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
