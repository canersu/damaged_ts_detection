# %%
import os
from PIL import Image
import numpy as np
import ae
import tensorflow as tf
from time import sleep
# Out:
# 2022-10-16 00:29:55.327795: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-16 00:29:55.480801: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-16 00:29:56.079225: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# ...

# %%
weight_file17 = "../ae_weights/17fullmodel1mse.h5"
ae17 = ae.autoEncoder()
model17 = ae17.loadModel(weight_file17)
test_path17 = "../gtsrb/damaged_signs/17/healthy/"
ae17.showResults(5, test_path17, model17, "ALL")
# Out:
# 2022-10-16 00:29:57.471021: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 00:29:57.476805: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2022-10-16 00:29:57.476821: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# ...

# %%
weight_file14 = "../ae_weights/14fullmodel1mse.h5"
ae14 = ae.autoEncoder()
model14 = ae14.loadModel(weight_file14)
test_path14 = "../gtsrb/damaged_signs/14/healthy/"
ae14.showResults(7, test_path14, model14, "ALL")
# Out:
# 1/1 [==============================] - 0s 172ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file13 = "../ae_weights/13fullmodel1mse.h5"
ae13 = ae.autoEncoder()
model13 = ae13.loadModel(weight_file13)
test_path13 = "../gtsrb/damaged_signs/13/healthy/"
ae13.showResults(3, test_path13, model13, "ALL")
# Out:
# 1/1 [==============================] - 0s 167ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file39 = "../ae_weights/39fullmodel1mse.h5"
ae39 = ae.autoEncoder()
model39 = ae39.loadModel(weight_file39)
test_path39 = "../gtsrb/damaged_signs/39/healthy/"
ae39.showResults(4, test_path39, model39, "ALL")
# Out:
# 1/1 [==============================] - 0s 167ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
weight_file1 = "../ae_weights/1fullmodel1mse.h5"
ae1 = ae.autoEncoder()
model1 = ae1.loadModel(weight_file1)
test_path1 = "../gtsrb/damaged_signs/1/healthy/"
ae1.showResults(6, test_path1, model1, "ALL")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc30a2a9d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 174ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
weight_file25 = "../ae_weights/25fullmodel1mse.h5"
ae25 = ae.autoEncoder()
model25 = ae25.loadModel(weight_file25)
test_path25 = "../gtsrb/damaged_signs/25/healthy/"
ae25.showResults(6, test_path25, model25, "ALL")
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc30599f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 171ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
weight_file9 = "../ae_weights/9fullmodel1mse.h5"
ae9 = ae.autoEncoder()
model9 = ae9.loadModel(weight_file9)
test_path9 = "../gtsrb/damaged_signs/9/healthy/"
ae9.showResults(3, test_path9, model9, "ALL")
# Out:
# 1/1 [==============================] - 0s 164ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
