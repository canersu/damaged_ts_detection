# %%
import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.7.0 (NVIDIA GeForce GTX 1070)

# %%
# !python3 ../yolov7/train.py --workers 8 --device 0 --batch-size 8 --data ../yolov7/data/gtsdb.yaml --img 640 640 --cfg ../yolov7/cfg/training/yolov7x.yaml --weights yolov7-x --name yolov7 --hyp ../yolov7/data/hyp.scratch.p5.yaml
# Out:
# YOLOR 🚀 v0.1-111-gb1850c7 torch 1.7.0 CUDA:0 (NVIDIA GeForce GTX 1070, 8116.5625MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='../yolov7/cfg/training/yolov7x.yaml', data='../yolov7/data/gtsdb.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='../yolov7/data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, weights='yolov7-x', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python3 ../yolov7/train.py --workers 8 --device 0 --batch-size 8 --data ../yolov7/data/gtsdb.yaml --img 640 640 --cfg ../yolov7/cfg/training/yolov7.yaml --weights yolov7 --name yolov7 --hyp ../yolov7/data/hyp.scratch.p5.yaml
# Out:
# YOLOR 🚀 v0.1-111-gb1850c7 torch 1.12.1+cu116 CUDA:0 (NVIDIA GeForce GTX 1070, 8116.5625MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='../yolov7/cfg/training/yolov7.yaml', data='../yolov7/data/gtsdb.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='../yolov7/data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov710', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, weights='yolov7', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...
