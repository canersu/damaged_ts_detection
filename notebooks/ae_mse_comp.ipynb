# %%
import os
from PIL import Image
import numpy as np
import ae
import tensorflow as tf
from time import sleep
# Out:
# 2022-10-13 17:14:00.005760: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-13 17:14:00.147047: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-13 17:14:00.761363: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2022-10-13 17:14:00.761454: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2022-10-13 17:14:00.761463: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
weight_file17 = "../ae_weights/17fullmodel1mse.h5"
ae17 = ae.autoEncoder()
model17 = ae17.loadModel(weight_file17)
test_path17 = "../gtsrb/damaged_noentry/web_imgs/"
ae17.showResults(5, test_path17, model17)
# Out:
# 2022-10-13 17:14:07.244499: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-13 17:14:07.253108: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64:
# 2022-10-13 17:14:07.253135: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-10-13 17:14:07.253788: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1/1 [==============================] - 0s 268ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor(0.059711006, shape=(), dtype=float32)
# tf.Tensor(0.049758725, shape=(), dtype=float32)
# tf.Tensor(0.041571267, shape=(), dtype=float32)
# tf.Tensor(0.04833179, shape=(), dtype=float32)
# tf.Tensor(0.019716926, shape=(), dtype=float32)

# %%
weight_file14 = "../ae_weights/14fullmodel1mse.h5"
ae14 = ae.autoEncoder()
model14 = ae14.loadModel(weight_file14)
test_path14 = "../gtsrb/damaged_signs/14/"
ae14.showResults(7, test_path14, model14)
# Out:
# 1/1 [==============================] - 0s 187ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor(0.041136708, shape=(), dtype=float32)
# tf.Tensor(0.045122284, shape=(), dtype=float32)
# tf.Tensor(0.025642173, shape=(), dtype=float32)
# tf.Tensor(0.03918782, shape=(), dtype=float32)
# tf.Tensor(0.041020837, shape=(), dtype=float32)
# tf.Tensor(0.063117914, shape=(), dtype=float32)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor(0.04223748, shape=(), dtype=float32)

# %%
weight_file13 = "../ae_weights/13fullmodel1mse.h5"
ae13 = ae.autoEncoder()
model13 = ae13.loadModel(weight_file13)
test_path13 = "../gtsrb/damaged_signs/13/"
ae13.showResults(3, test_path13, model13)
# Out:
# 1/1 [==============================] - 0s 213ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor(0.05799652, shape=(), dtype=float32)
# tf.Tensor(0.03666858, shape=(), dtype=float32)
# tf.Tensor(0.026851831, shape=(), dtype=float32)

# %%
weight_file39 = "../ae_weights/39fullmodel1mse.h5"
ae39 = ae.autoEncoder()
model39 = ae39.loadModel(weight_file39)
test_path39 = "../gtsrb/damaged_signs/39/"
ae39.showResults(4, test_path39, model39)
# Out:
# 1/1 [==============================] - 0s 181ms/step
# tf.Tensor(0.09040351, shape=(), dtype=float32)
# tf.Tensor(0.075702615, shape=(), dtype=float32)
# tf.Tensor(0.05810158, shape=(), dtype=float32)
# tf.Tensor(0.037870508, shape=(), dtype=float32)

# %%
weight_file1 = "../ae_weights/1fullmodel1mse.h5"
ae1 = ae.autoEncoder()
model1 = ae1.loadModel(weight_file1)
test_path1 = "../gtsrb/damaged_signs/1/"
ae1.showResults(6, test_path1, model1)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0ccd1e3f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 175ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor(0.061165262, shape=(), dtype=float32)
# tf.Tensor(0.086123995, shape=(), dtype=float32)
# tf.Tensor(0.011997961, shape=(), dtype=float32)
# tf.Tensor(0.047634903, shape=(), dtype=float32)
# tf.Tensor(0.02899793, shape=(), dtype=float32)
# tf.Tensor(0.031014394, shape=(), dtype=float32)

# %%
weight_file25 = "../ae_weights/25fullmodel1mse.h5"
ae25 = ae.autoEncoder()
model25 = ae25.loadModel(weight_file25)
test_path25 = "../gtsrb/damaged_signs/25/"
ae25.showResults(6, test_path25, model25)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0cccbea940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 193ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor(0.10777944, shape=(), dtype=float32)
# tf.Tensor(0.073805034, shape=(), dtype=float32)
# tf.Tensor(0.081153534, shape=(), dtype=float32)
# tf.Tensor(0.03480598, shape=(), dtype=float32)
# tf.Tensor(0.040289674, shape=(), dtype=float32)
# tf.Tensor(0.027120622, shape=(), dtype=float32)

# %%
weight_file9 = "../ae_weights/9fullmodel1mse.h5"
ae9 = ae.autoEncoder()
model9 = ae9.loadModel(weight_file9)
test_path9 = "../gtsrb/damaged_signs/9/"
ae9.showResults(3, test_path9, model9)
# Out:
# 1/1 [==============================] - 0s 178ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor(0.032848734, shape=(), dtype=float32)
# tf.Tensor(0.044170856, shape=(), dtype=float32)
# tf.Tensor(0.058736235, shape=(), dtype=float32)
